# %%
from common_functions import ret_metabase

# %%
df = ret_metabase("egypt", 61041)
# Out:
# /home/ec2-user/service_account_key.json

# %%
df
# Out:
#                   CREATED_AT                                    ID  \
# 0    2025-06-25T06:45:04.211  5df6de95-5364-4948-962c-7579140f7d32
# 1    2025-06-25T06:45:04.211  275c81d5-6b78-45a9-a6c8-9c54921d154e
# 2    2025-06-25T06:45:04.211  47254969-fe55-4e92-a498-be0ee62e7b06
# 3    2025-06-25T06:45:04.211  bf4b5f6c-6360-4737-be81-f0f87aa980fe
# 4    2025-06-25T06:45:04.211  e404a2d8-b60c-4ad7-8b2b-fad906f450e4
# ..                       ...                                   ...
# 305  2025-06-25T06:45:04.211  b6ae746a-d599-4b96-960c-674fd050b6a5
# 306  2025-06-25T06:45:04.211  76b10fac-8913-4b6e-a94d-c66088d8c18f
# 307  2025-06-25T06:45:04.211  c20573a9-0e12-48b5-aa35-dead8d094522
# 308  2025-06-25T06:45:04.211  e89d2053-67ad-4e55-a618-1416a9014127
# 309  2025-06-25T06:45:04.211  112b264f-6e96-4f0b-a536-4599a5bd016b
#
#            TASK_TYPE                                         TASK_TITLE  \
# 0    seller_followup  Follow up on seller: جملة الاخوة المنشية - كشك...
# ...

# %%
query_2 = ret_metabase("Egypt", 61071)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/ec2-user/service_account_key.json

# %%
query_2
# Out:
#        MAIN_SYSTEM_ID                                              OFFER
# 0              566962  Project: orange_etisalat_cash, اشحن من محافظ ا...
# 1              752056  Project: orange_etisalat_cash, اشحن من محافظ ا...
# 2              746791  Project: orange_etisalat_cash, اشحن من محافظ ا...
# 3              782328  Project: orange_etisalat_cash, اشحن من محافظ ا...
# 4              691151  Project: orange_etisalat_cash, اشحن من محافظ ا...
# ...               ...                                                ...
# 15307          868789  Project: orange_etisalat_cash, اشحن من محافظ ا...
# 15308          728478  Project: orange_etisalat_cash, اشحن من محافظ ا...
# 15309          713378  Project: orange_etisalat_cash, اشحن من محافظ ا...
# 15310          783089  Project: orange_etisalat_cash, اشحن من محافظ ا...
# 15311          633640  Project: orange_etisalat_cash, اشحن من محافظ ا...
#
# [15312 rows x 2 columns]

# %%
snowflake_query("Egypt", df=query_2, "FINTECH", "AM_retailes_offers"
