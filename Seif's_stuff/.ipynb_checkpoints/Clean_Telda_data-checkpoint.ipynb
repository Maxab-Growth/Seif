# %%
from common_functions import ret_metabase, google_sheets, upload_dataframe_to_snowflake, snowflake_query, upload_dataframe_to_pg, dwh_query, initialize_env
import pandas as pd
from datetime import datetime, timedelta
import datetime as dt
import time
import os
import boto3
import base64
from botocore.exceptions import ClientError
import json
import requests
from pathlib import Path
from io import StringIO
import pandas as pd
# import psycopg2
import numpy as np
import gspread
import pytz

# %%
df = pd.read_excel('telda_CS.xlsx')
df
# Out:
#        Ticket ID                                Subject  \
# 0        1281374         Conversation with Anas Mohamed
# 1        1281375        Conversation with Mazen Babiker
# 2        1281376          Conversation with Adhma Ahmed
# 3        1281377          Conversation with Marwan Amin
# 4        1281378         Conversation with Yasmin Osama
# ...          ...                                    ...
# 40164    1321551  Conversation with Omar Mohamed Rashad
# 40165    1321552         Conversation with Yassin Walid
# 40166    1321553          Conversation with kero_.karam
# 40167    1321554        Conversation with Jasmine Ahmed
# 40168    1321555           Conversation with حنين محمود
#
# ...

# %%
# Extract full name after 'Conversation with '
df['Name'] = df['Subject'].str.extract(r'Conversation with (.+)')

df
# Out:
#        Ticket ID                                Subject  \
# 0        1281374         Conversation with Anas Mohamed
# 1        1281375        Conversation with Mazen Babiker
# 2        1281376          Conversation with Adhma Ahmed
# 3        1281377          Conversation with Marwan Amin
# 4        1281378         Conversation with Yasmin Osama
# ...          ...                                    ...
# 40164    1321551  Conversation with Omar Mohamed Rashad
# 40165    1321552         Conversation with Yassin Walid
# 40166    1321553          Conversation with kero_.karam
# 40167    1321554        Conversation with Jasmine Ahmed
# 40168    1321555           Conversation with حنين محمود
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Ticket ID', 'Subject', 'Description', 'Status', 'Priority', 'Source', 'Type', 'Agent', 'Group', 'Created time', 'Due by Time', 'Resolved time', 'Closed time', 'Last update time', 'Initial response time', 'Time tracked', 'First response time (in hrs)', 'Resolution time (in hrs)', 'Agent interactions', 'Customer interactions', 'Resolution status', 'First response status', 'Tags', 'Survey results', 'Product', 'Main Category', 'Every response status', 'Product.1', 'Summary', 'Sub Cat 2', 'Location', 'Telda Group Name', 'User ID', 'Mobile Number', '@username', 'Telda Agent Name', 'App Version', 'OS', 'Name']

# %%
df = df.head(5)
df = df[['Description', 'Name', 'Agent' ]]
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
pd.set_option('display.max_colwidth', None)

df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
import pandas as pd
import re

# Example DataFrame

# Function to remove client's parts
def remove_client_segments(row):
    name = re.escape(row['Name'])  # escape in case name has regex special chars
    text = row['Description']
    # remove all occurrences of "Name ... ," pattern
    cleaned = re.sub(fr'{name}[^,]*,', '', text)
    return cleaned

# Apply the function
df['Cleaned_Description'] = df.apply(remove_client_segments, axis=1)

# %%
pd.set_option('display.max_colwidth', None)

df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
