# %%
import pandas as pd
import requests
import json
from common_functions import ret_metabase
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = ret_metabase("egypt", 63184)
# Out:
# /home/ec2-user/service_account_key.json

# %%
df.head(5)
# Out:
#    MAIN_SYSTEM_ID  LOANS_TARGET  LOANS_ACTUAL  LOANS_ACHIEVED  AT_TARGET  \
# 0          666788        289900       34111.0           False        200
# 1          739516        354400           0.0           False        200
# 2          654939        291600       67587.0           False        200
# 3           32565        232600      194257.0           False        605
# 4          709483        249900       14262.0           False        200
#
#    AT_ACTUAL  AIRTIME_ACHIEVED  UT_TARGET  UT_ACTUAL  UTILITIES_ACHIEVED  \
# 0          2             False         50          0               False
# 1          0             False         50          0               False
# 2          0             False         50          0               False
# 3        113             False         50         20               False
# 4          0             False         50          0               False
#
#    REWARD
# 0     600
# 1     600
# 2     600
# 3     560
# 4     545

# %%
print(df.columns.tolist())
# Out:
# ['MAIN_SYSTEM_ID', 'LOANS_TARGET', 'LOANS_ACTUAL', 'LOANS_ACHIEVED', 'AT_TARGET', 'AT_ACTUAL', 'AIRTIME_ACHIEVED', 'UT_TARGET', 'UT_ACTUAL', 'UTILITIES_ACHIEVED', 'REWARD']

# %%
    # Replace with your WonderPush API key
    API_KEY = "YjFkMmExOWFlN2IxNzQzYzFlMzA4YThhNmE4ZDgwZmFiNmFlNTM2ODVhODhjMzM1NjA3NWU0MWI3M2YxYTZmYw"


    try:
        # Read the Excel file into a pandas DataFrame

        # Check if the required columns exist
        if not all(col in df.columns for col in ['MAIN_SYSTEM_ID', 'LOANS_TARGET', 'LOANS_ACTUAL', 'LOANS_ACHIEVED', 'AT_TARGET', 'AT_ACTUAL', 'AIRTIME_ACHIEVED', 'UT_TARGET', 'UT_ACTUAL', 'UTILITIES_ACHIEVED']):
            raise ValueError("Datafram1e missing some columns")

        # Iterate over the rows in the DataFrame
        for index, row in df.iterrows():
            user_id = f"EG_retailers_{int(row['MAIN_SYSTEM_ID'])}"

            CONDITION1 = int(row['AT_TARGET']),
            CONDITION1_PROGRESS = int(row['AT_ACTUAL']),
            CONDITION1_ACHIEVED = str(row['AIRTIME_ACHIEVED']),

            CONDITION2 = int(row['UT_TARGET']),
            CONDITION2_PROGRESS = int(row['UT_ACTUAL']),
            CONDITION2_ACHIEVED = str(row['UTILITIES_ACHIEVED']),

            CONDITION3 = int(row['LOANS_TARGET']),
            CONDITION3_PROGRESS = int(row['LOANS_ACTUAL']),
            CONDITION3_ACHIEVED = str(row['LOANS_ACHIEVED']),

            REWARD = int(row['REWARD']),


            patch_body = {"custom":{
            "int_CONDITION1": CONDITION1,
            "int_CONDITION1_PROGRESS": CONDITION1_PROGRESS,
            "string_CONDITION1_ACHIEVED" : CONDITION1_ACHIEVED,
            "int_CONDITION2": CONDITION2,
            "int_CONDITION2_PROGRESS": CONDITION2_PROGRESS,
            "string_CONDITION2_ACHIEVED": CONDITION2_ACHIEVED,
            "int_CONDITION3": CONDITION3,
            "int_CONDITION3_PROGRESS": CONDITION3_PROGRESS,
            "string_CONDITION3_ACHIEVED": CONDITION3_ACHIEVED,
            "int_REWARD": REWARD }}


            url = f"https://management-api.wonderpush.com/v1/users/{user_id}?accessToken={API_KEY}"
            headers = {"Content-Type": "application/json"}
            response = requests.patch(url, headers=headers, json=patch_body)

            # Check the response status code
            if response.status_code == 200:
                print(f"Successfully set properties for user '{user_id}'")
            else:
                print(f"Error setting property for user '{user_id}': {response.status_code} - {response.text}")

    except FileNotFoundError:
        print(f"Error: File '{EXCEL_FILE}' not found.")
    except ValueError as e:
        print(f"Error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
# Out:
# Error setting property for user 'EG_retailers_739516': 202 - {"success":true}
# Error setting property for user 'EG_retailers_654939': 202 - {"success":true}
# Error setting property for user 'EG_retailers_666788': 202 - {"success":true}
# Error setting property for user 'EG_retailers_32565': 202 - {"success":true}
# Error setting property for user 'EG_retailers_709483': 202 - {"success":true}
# Error setting property for user 'EG_retailers_663604': 202 - {"success":true}
# Error setting property for user 'EG_retailers_666989': 202 - {"success":true}
# Error setting property for user 'EG_retailers_716583': 202 - {"success":true}
# Error setting property for user 'EG_retailers_391261': 202 - {"success":true}
# Error setting property for user 'EG_retailers_662643': 202 - {"success":true}
# Error setting property for user 'EG_retailers_668864': 202 - {"success":true}
# Error setting property for user 'EG_retailers_719479': 202 - {"success":true}
# ...

# %%
df = ret_metabase("Egypt", 63979)
print(df.columns.tolist())
df.head()
# Out:
# /home/ec2-user/service_account_key.json
# ['MAIN_SYSTEM_ID', 'PRODUCT_ID', 'PACKING_UNIT_ID', 'PRICE', 'PRODUCT_NMV', 'AVAILABLE_STOCK', 'LAST_PR_TS', 'IMAGE_LINK', 'PRODUCT_NAME', 'GROUP_TYPE', 'R', 'DEEPLINK']
#    MAIN_SYSTEM_ID  PRODUCT_ID  PACKING_UNIT_ID   PRICE  PRODUCT_NMV  \
# 0              81          33                1  265.50       270.75
# 1              81          35                1  264.75       270.75
# 2              84          82                2  486.75       456.25
# 3              84          83                2  543.00       516.50
# 4              84          84                2  436.50       416.25
#
#    AVAILABLE_STOCK               LAST_PR_TS  \
# 0              465  2025-09-04T15:09:10.289
# 1              350  2025-09-04T15:09:10.289
# 2              296   2025-09-04T11:09:08.44
# 3              666   2025-09-04T11:09:08.44
# 4              270   2025-09-04T11:09:08.44
#
#                                           IMAGE_LINK  \
# ...

# %%
df
# Out:
#     MAIN_SYSTEM_ID  PRODUCT_ID  PACKING_UNIT_ID   PRICE  PRODUCT_NMV  \
# 0               81          33                1  265.50       270.75
# 1               81          35                1  264.75       270.75
# 2               84          82                2  486.75       456.25
# 3               84          83                2  543.00       516.50
# 4               84          84                2  436.50       416.25
# 5               96          84                2  436.50       832.50
# 6              178          83                2  543.00       537.50
# 7              178         593                2  128.50       623.50
# 8              178        1006                2  128.00       623.50
# 9              178       10825               21   42.25       602.00
# 10             203          82                2  486.75       476.70
# 11             203          83                2  543.00      2678.55
# 12             203        5730                2  510.00       505.75
# ...

# %%
df = df.head()
df['user_id'] = "EG_retailers_198957"
df
# Out:
#    MAIN_SYSTEM_ID  PRODUCT_ID  PACKING_UNIT_ID   PRICE  PRODUCT_NMV  \
# 0              81         107                2  609.25      2088.25
# 1              84        1776                1  223.00       223.00
# 2              84       11404                2  285.25       591.00
# 3             106          97               11   56.00      5570.40
# 4             109        5083                2  238.00      1425.30
#
#    AVAILABLE_STOCK               LAST_PR_TS  \
# 0              655  2025-09-01T16:09:11.909
# 1              665  2025-09-01T20:09:11.266
# 2              409  2025-09-03T15:09:07.808
# 3              147  2025-09-02T20:09:07.794
# 4              248  2025-08-31T13:11:43.415
#
#                                           IMAGE_LINK  \
# 0  https://cdn.maxab.info/uploads/products/107/sm...
# 1  https://cdn.maxab.info/uploads/products/1776/s...
# 2  https://cdn.maxab.info/uploads/products/11404/...
# 3  https://cdn.maxab.info/uploads/products/97/sma...
# ...

# %%
from datetime import datetime, timedelta
# Replace with your WonderPush API key
API_KEY = "YjFkMmExOWFlN2IxNzQzYzFlMzA4YThhNmE4ZDgwZmFiNmFlNTM2ODVhODhjMzM1NjA3NWU0MWI3M2YxYTZmYw"

df = ret_metabase("Egypt", 63979)
df['user_id'] = 'EG_retailers_' + df['MAIN_SYSTEM_ID'].astype(str)
try:
    # Read the Excel file into a pandas DataFrame

    # Check if the required columns exist
    if not all(col in df.columns for col in ['MAIN_SYSTEM_ID', 'PRODUCT_ID', 'PACKING_UNIT_ID', 'PRICE', 'AVAILABLE_STOCK', 'LAST_PR_TS', 'IMAGE_LINK', 'PRODUCT_NAME']):
            raise ValueError("Datafram1e missing some columns")
    # Iterate over the rows in the DataFrame

    now = datetime.now() + timedelta(hours=3)

 
    for user_id, group in df.groupby("user_id"):
        products = [
            {"name": row["PRODUCT_NAME"], "image": row["IMAGE_LINK"], "price": row["PRICE"]}
            for _, row in group.iterrows()]
        
        json_string = json.dumps(products, ensure_ascii=False)

        # Build the PATCH body: only the field you want to change under "custom"
        patch_body = {
            "custom": {
                "string_mpproducts": json_string,
                "date_dispatched_at": now.isoformat()
            }
        }

        # Send a PATCH to /v1/users/{userId}
        url = (
            f"https://management-api.wonderpush.com/v1/users/{user_id}"
            f"?accessToken={API_KEY}"
        )
        headers = {"Content-Type": "application/json"}
        response = requests.patch(url, headers=headers, json=patch_body)

        if response.status_code == 200:
            print(f"✅ Patched string_mpproducts for user {user_id}")
        else:
            print(f"❌ Error for {user_id}: {response.status_code} – {response.text}")

except ValueError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# /home/ec2-user/service_account_key.json
# ❌ Error for EG_retailers_100018: 202 – {"success":true}
# ❌ Error for EG_retailers_10004: 202 – {"success":true}
# ❌ Error for EG_retailers_100040: 202 – {"success":true}
# ❌ Error for EG_retailers_100050: 202 – {"success":true}
# ❌ Error for EG_retailers_100060: 202 – {"success":true}
# ❌ Error for EG_retailers_100081: 202 – {"success":true}
# ❌ Error for EG_retailers_100085: 202 – {"success":true}
# ❌ Error for EG_retailers_100103: 202 – {"success":true}
# ❌ Error for EG_retailers_100138: 202 – {"success":true}
# ❌ Error for EG_retailers_100157: 202 – {"success":true}
# ❌ Error for EG_retailers_100164: 202 – {"success":true}
# ❌ Error for EG_retailers_100195: 202 – {"success":true}
# ❌ Error for EG_retailers_10020: 202 – {"success":true}
# ❌ Error for EG_retailers_100209: 202 – {"success":true}
# ❌ Error for EG_retailers_10021: 202 – {"success":true}
# ❌ Error for EG_retailers_100216: 202 – {"success":true}
# ...

# %%
df = pd.read_excel("upload_df.xlsx")

# Display the first few rows
df.head()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    RETAILER_ID  CURRENT_COUPON_TOTAL_VALUE  CURRENT_COUPON_COUNT  \
# 0        40477                          20                     1
# 1       620290                          20                     1
# 2       606362                          20                     1
# 3        22690                         100                     1
# 4       676120                         100                     1
#
#           RETAILER_TAG      MOBILE     NAME   LAST_CALL_ATTEMPT  \
# 0  first order october  1111958785  ام حسام 2025-10-11 17:22:58
# 1  first order october  1069651155    غاندي                 NaT
# 2  first order october  1127885063     علاء 2025-10-12 11:08:04
# 3          Acquisition  1016579030     محمد 2025-10-05 18:13:20
# ...

# %%
df = pd.DataFrame([
    {
        "RETAILER_ID": 198957,
        "CURRENT_COUPON_TOTAL_VALUE": 20,
        "CURRENT_COUPON_COUNT": 1,
        "RETAILER_TAG": "first order october",
        "MOBILE": "1111958785",
        "NAME": "ام حسام",
        "LAST_CALL_ATTEMPT": "2025-10-11 17:22:58",
        "LAST_REACHABLE_CALL": "2025-10-11 17:22:58",
        "LAST_ONGROUND_VISIT": "2025-10-12 13:50:20.961",
        "LAST_ONGROUND_DISPATCHED": "2025-10-12",
    }
])

df
# Out:
#    RETAILER_ID  CURRENT_COUPON_TOTAL_VALUE  CURRENT_COUPON_COUNT  \
# 0       198957                          20                     1
#
#           RETAILER_TAG      MOBILE     NAME    LAST_CALL_ATTEMPT  \
# 0  first order october  1111958785  ام حسام  2025-10-11 17:22:58
#
#    LAST_REACHABLE_CALL      LAST_ONGROUND_VISIT LAST_ONGROUND_DISPATCHED
# 0  2025-10-11 17:22:58  2025-10-12 13:50:20.961               2025-10-12

# %%
import requests
for i in df:
    
    user = df['RETAILER_ID'].iloc[i]
    copoun_value = df['CURRENT_COUPON_TOTAL_VALUE'].iloc[i]
    
    url = "https://management-api.wonderpush.com/v1/deliveries"

    querystring = {"accessToken":"YjFkMmExOWFlN2IxNzQzYzFlMzA4YThhNmE4ZDgwZmFiNmFlNTM2ODVhODhjMzM1NjA3NWU0MWI3M2YxYTZmYw"}

    payload = {
        "targetUserIds": ["EG_retailers_198957"],
        "notification": {
            "alert": {
                "text": "Testing deeplink ",
                "targetUrl": "https://maxab.page.link?deep_link=myApp://marketPlaceHomeFragment"
            }
        }
    }
    headers = {"Content-Type": "application/json"}

    response = requests.request("POST", url, json=payload, headers=headers, params=querystring)

    print(response.text)
# Out:
# ❌ Error for EG_retailers_299600: 202 – {"success":true}

# %%
curl -XPOST https://management-api.wonderpush.com/v1/deliveries?accessToken=API_KEY \
  -d targetSegmentIds= \
  -d notification='{"alert":{"text":"Hello World!"}}'

# %%
from datetime import datetime, timedelta
# Replace with your WonderPush API key
API_KEY = "YjFkMmExOWFlN2IxNzQzYzFlMzA4YThhNmE4ZDgwZmFiNmFlNTM2ODVhODhjMzM1NjA3NWU0MWI3M2YxYTZmYw"


df['user_id'] = 'EG_retailers_' + df['RETAILER_ID'].astype(str)
try:
    # Read the Excel file into a pandas DataFrame

    # Check if the required columns exist
    # if not all(col in df.columns for col in ['MAIN_SYSTEM_ID', 'PRODUCT_ID', 'PACKING_UNIT_ID', 'PRICE', 'AVAILABLE_STOCK', 'LAST_PR_TS', 'IMAGE_LINK', 'PRODUCT_NAME']):
    #         raise ValueError("Datafram1e missing some columns")
    # Iterate over the rows in the DataFrame

    now = datetime.now() + timedelta(hours=3)

 
    for user_id, group in df.groupby("user_id"):
        products = [
            {"name": row["PRODUCT_NAME"], "image": row["IMAGE_LINK"], "price": row["PRICE"]}
            for _, row in group.iterrows()]
        
        json_string = json.dumps(products, ensure_ascii=False)

        # Build the PATCH body: only the field you want to change under "custom"
        patch_body = {
            "custom": {
                "string_send_to": "Yes",
                "int_coupoun_value": df["CURRENT_COUPON_TOTAL_VALUE"].iloc[0]
            }
        }

        # Send a PATCH to /v1/users/{userId}
        url = (
            f"https://management-api.wonderpush.com/v1/users/{user_id}"
            f"?accessToken={API_KEY}"
        )
        headers = {"Content-Type": "application/json"}
        response = requests.patch(url, headers=headers, json=patch_body)

        if response.status_code == 200:
            print(f"✅ Patched string_mpproducts for user {user_id}")
        else:
            print(f"❌ Error for {user_id}: {response.status_code} – {response.text}")

except ValueError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
